# %%
import pandas as pd
import numpy as np

# %%
dir = 'Seoul_Commercial_Area_Subway/CommercialAreaData/2021/서울_상권_매출_2021.csv'
data = pd.read_csv(dir, encoding='cp949')

# %%
data.isnull().sum()
# Out:
# 상권_구분_코드           0
# 상권_구분_코드_명         0
# 상권_코드              0
# 상권_코드_명            0
# 서비스_업종_코드          0
#                   ..
# 연령대_40_매출_건수       0
# 연령대_50_매출_건수       0
# 연령대_60_이상_매출_건수    0
# 점포수                0
# 분기                 0
# Length: 79, dtype: int64

# %%
data.describe()
# Out:
#               상권_코드     분기당_매출_금액     분기당_매출_건수      주중_매출_비율      주말_매출_비율  \
# count  9.689500e+04  9.689500e+04  9.689500e+04  96895.000000  96895.000000
# mean   1.000778e+06  5.498975e+08  2.117108e+04     76.459611     23.629011
# std    4.211068e+02  4.322653e+09  8.507154e+04     16.302317     16.314609
# min    1.000001e+06  1.700000e+02  1.000000e+00      0.000000      0.000000
# 25%    1.000415e+06  2.284128e+07  4.270000e+02     67.000000     12.000000
# 50%    1.000818e+06  8.670058e+07  2.317000e+03     76.000000     24.000000
# 75%    1.001133e+06  3.212620e+08  1.251150e+04     88.000000     33.000000
# max    1.001496e+06  4.408316e+11  4.494433e+06    100.000000    100.000000
#
#           월요일_매출_비율     화요일_매출_비율     수요일_매출_비율     목요일_매출_비율     금요일_매출_비율  \
# count  96895.000000  96895.000000  96895.000000  96895.000000  96895.000000
# mean      15.069808     15.041870     15.280066     15.112018     16.139945
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96895 entries, 0 to 96894
# Data columns (total 79 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   상권_구분_코드         96895 non-null  category
#  1   상권_구분_코드_명       96895 non-null  category
#  2   상권_코드            96895 non-null  int64
#  3   상권_코드_명          96895 non-null  object
#  4   서비스_업종_코드        96895 non-null  category
#  5   서비스_업종_코드_명      96895 non-null  category
#  6   분기당_매출_금액        96895 non-null  int64
#  7   분기당_매출_건수        96895 non-null  int64
#  8   주중_매출_비율         96895 non-null  int64
#  9   주말_매출_비율         96895 non-null  int64
#  10  월요일_매출_비율        96895 non-null  int64
#  11  화요일_매출_비율        96895 non-null  int64
#  12  수요일_매출_비율        96895 non-null  int64
#  13  목요일_매출_비율        96895 non-null  int64
#  14  금요일_매출_비율        96895 non-null  int64
#  15  토요일_매출_비율        96895 non-null  int64
# ...

# %%
dir = 'sales_quarter_2019.csv'
df1 = pd.read_csv(dir, encoding='utf8')

# %%
df1
# Out:
#           상권_코드 서비스_업종_코드          분기  분기당_매출_금액  분기당_매출_건수
# 0       1000985  CS200003  2019-01-01   20061598        125
# 1       1000267  CS200037  2019-01-01     510636         21
# 2       1001445  CS300027  2019-01-01    4038928         33
# 3       1000789  CS300017  2019-01-01    5085873         10
# 4       1000930  CS200001  2019-01-01     527027         53
# ...         ...       ...         ...        ...        ...
# 135573  1001469  CS300011  2019-10-01   14282341         48
# 135574  1000181  CS100004  2019-10-01  562291801      23923
# 135575  1000441  CS300002  2019-10-01  518371562      81848
# 135576  1001044  CS200001  2019-10-01   15509601         56
# 135577  1000736  CS300002  2019-10-01  218997663      32143
#
# [135578 rows x 5 columns]

# %%
pd.pivot_table(df1, index=['상권_코드', '분기'], values=['분기당_매출_금액', '분기당_매출_건수'], aggfunc='sum')
# Out:
#                     분기당_매출_건수     분기당_매출_금액
# 상권_코드   분기
# 1000001 2019-01-01     247105    3373980252
#         2019-04-01     248606    3329090192
#         2019-07-01     288072    3751287591
#         2019-10-01     327881    6001522895
# 1000002 2019-01-01     285188    5786105171
# ...                       ...           ...
# 1001495 2019-10-01    7326009  185236137810
# 1001496 2019-01-01    4649493  168780617914
#         2019-04-01    4768635  173926103805
#         2019-07-01    5033855  178673833204
#         2019-10-01    5651866  223148474178
#
# [5945 rows x 2 columns]
